# %% [markdown]
# Sample EDA of the [Oxford Covid-19 Government Response Tracker (OxCGRT)](https://github.com/OxCGRT/covid-policy-tracker) dataset

# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv('OxCGRT_latest.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_usa = data[data['CountryCode']=='USA']

#drop nationwide data
data_usa = data_usa.dropna(subset=['RegionName'])

#convert int date to datetime
data_usa['Datetime'] = pd.to_datetime(data_usa['Date'], format='%Y%m%d')

# %%
data_usa.head()
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 162792  United States         USA     Alaska      US_AK  STATE_TOTAL
# 162793  United States         USA     Alaska      US_AK  STATE_TOTAL
# 162794  United States         USA     Alaska      US_AK  STATE_TOTAL
# 162795  United States         USA     Alaska      US_AK  STATE_TOTAL
# 162796  United States         USA     Alaska      US_AK  STATE_TOTAL
#
#             Date  C1_School closing  C1_Flag  C2_Workplace closing  C2_Flag  \
# 162792  20200101                0.0      NaN                   0.0      NaN
# 162793  20200102                0.0      NaN                   0.0      NaN
# 162794  20200103                0.0      NaN                   0.0      NaN
# 162795  20200104                0.0      NaN                   0.0      NaN
# 162796  20200105                0.0      NaN                   0.0      NaN
#
#         ...  StringencyIndexForDisplay  StringencyLegacyIndex  \
# 162792  ...                        0.0                    0.0
# 162793  ...                        0.0                    0.0
# 162794  ...                        0.0                    0.0
# 162795  ...                        0.0                    0.0
# 162796  ...                        0.0                    0.0
#
#         StringencyLegacyIndexForDisplay  GovernmentResponseIndex  \
# 162792                              0.0                      0.0
# 162793                              0.0                      0.0
# 162794                              0.0                      0.0
# 162795                              0.0                      0.0
# 162796                              0.0                      0.0
#
#         GovernmentResponseIndexForDisplay  ContainmentHealthIndex  \
# 162792                                0.0                     0.0
# 162793                                0.0                     0.0
# 162794                                0.0                     0.0
# 162795                                0.0                     0.0
# 162796                                0.0                     0.0
#
#         ContainmentHealthIndexForDisplay  EconomicSupportIndex  \
# 162792                               0.0                   0.0
# 162793                               0.0                   0.0
# 162794                               0.0                   0.0
# 162795                               0.0                   0.0
# 162796                               0.0                   0.0
#
#         EconomicSupportIndexForDisplay   Datetime
# 162792                             0.0 2020-01-01
# 162793                             0.0 2020-01-02
# 162794                             0.0 2020-01-03
# 162795                             0.0 2020-01-04
# 162796                             0.0 2020-01-05
#
# [5 rows x 52 columns]

# %%
data_usa.columns
# Out:
# Index(['CountryName', 'CountryCode', 'RegionName', 'RegionCode',
#        'Jurisdiction', 'Date', 'C1_School closing', 'C1_Flag',
#        'C2_Workplace closing', 'C2_Flag', 'C3_Cancel public events', 'C3_Flag',
#        'C4_Restrictions on gatherings', 'C4_Flag', 'C5_Close public transport',
#        'C5_Flag', 'C6_Stay at home requirements', 'C6_Flag',
#        'C7_Restrictions on internal movement', 'C7_Flag',
#        'C8_International travel controls', 'E1_Income support', 'E1_Flag',
#        'E2_Debt/contract relief', 'E3_Fiscal measures',
#        'E4_International support', 'H1_Public information campaigns',
#        'H1_Flag', 'H2_Testing policy', 'H3_Contact tracing',
#        'H4_Emergency investment in healthcare', 'H5_Investment in vaccines',
#        'H6_Facial Coverings', 'H6_Flag', 'H7_Vaccination policy', 'H7_Flag',
#        'H8_Protection of elderly people', 'H8_Flag', 'M1_Wildcard',
#        'ConfirmedCases', 'ConfirmedDeaths', 'StringencyIndex',
#        'StringencyIndexForDisplay', 'StringencyLegacyIndex',
#        'StringencyLegacyIndexForDisplay', 'GovernmentResponseIndex',
#        'GovernmentResponseIndexForDisplay', 'ContainmentHealthIndex',
#        'ContainmentHealthIndexForDisplay', 'EconomicSupportIndex',
#        'EconomicSupportIndexForDisplay', 'Datetime'],
#       dtype='object')

# %%
data_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32946 entries, 162792 to 195737
# Data columns (total 52 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   CountryName                            32946 non-null  object
#  1   CountryCode                            32946 non-null  object
#  2   RegionName                             32946 non-null  object
#  3   RegionCode                             32946 non-null  object
#  4   Jurisdiction                           32946 non-null  object
#  5   Date                                   32946 non-null  int64
#  6   C1_School closing                      32529 non-null  float64
#  7   C1_Flag                                27250 non-null  float64
#  8   C2_Workplace closing                   32491 non-null  float64
#  9   C2_Flag                                24548 non-null  float64
#  10  C3_Cancel public events                32501 non-null  float64
#  11  C3_Flag                                27197 non-null  float64
#  12  C4_Restrictions on gatherings          32544 non-null  float64
#  13  C4_Flag                                20453 non-null  float64
#  14  C5_Close public transport              32526 non-null  float64
#  15  C5_Flag                                11105 non-null  float64
#  16  C6_Stay at home requirements           32515 non-null  float64
#  17  C6_Flag                                21627 non-null  float64
#  18  C7_Restrictions on internal movement   32472 non-null  float64
#  19  C7_Flag                                28687 non-null  float64
#  20  C8_International travel controls       32508 non-null  float64
#  21  E1_Income support                      32365 non-null  float64
#  22  E1_Flag                                25542 non-null  float64
#  23  E2_Debt/contract relief                32455 non-null  float64
#  24  E3_Fiscal measures                     12047 non-null  float64
#  25  E4_International support               11919 non-null  float64
#  26  H1_Public information campaigns        32529 non-null  float64
#  27  H1_Flag                                30269 non-null  float64
#  28  H2_Testing policy                      32545 non-null  float64
#  29  H3_Contact tracing                     32414 non-null  float64
#  30  H4_Emergency investment in healthcare  11851 non-null  float64
#  31  H5_Investment in vaccines              12655 non-null  float64
#  32  H6_Facial Coverings                    32029 non-null  float64
#  33  H6_Flag                                27298 non-null  float64
#  34  H7_Vaccination policy                  15439 non-null  float64
#  35  H7_Flag                                14706 non-null  float64
#  36  H8_Protection of elderly people        32321 non-null  float64
#  37  H8_Flag                                28744 non-null  float64
#  38  M1_Wildcard                            0 non-null      float64
#  39  ConfirmedCases                         31773 non-null  float64
#  40  ConfirmedDeaths                        31773 non-null  float64
#  41  StringencyIndex                        32460 non-null  float64
#  42  StringencyIndexForDisplay              32460 non-null  float64
#  43  StringencyLegacyIndex                  32514 non-null  float64
#  44  StringencyLegacyIndexForDisplay        32514 non-null  float64
#  45  GovernmentResponseIndex                32460 non-null  float64
#  46  GovernmentResponseIndexForDisplay      32460 non-null  float64
#  47  ContainmentHealthIndex                 32472 non-null  float64
#  48  ContainmentHealthIndexForDisplay       32472 non-null  float64
#  49  EconomicSupportIndex                   32257 non-null  float64
#  50  EconomicSupportIndexForDisplay         32257 non-null  float64
#  51  Datetime                               32946 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(45), int64(1), object(5)
# memory usage: 13.3+ MB

# %% [markdown]
# ## See vaccination policy by region

# %%
from states_dictionary import*

us_state_to_code = us_state_to_code()
states_to_regionChr = states_to_regionChr()
regionchr_to_regioncode = regionchr_to_regioncode()

regioncodes = []
for region in data_usa['RegionName'].values:
    abbrev = us_state_to_code[region]
    regionChr = states_to_regionChr[abbrev]
    regioncode = regionchr_to_regioncode[regionChr]
    regioncodes.append(regioncode)
    
data_usa['RegionCat'] = regioncodes

# %%
#only look at data between 2020-12-1 and 2021-6-1 (when policy change is happening)

data_usa_time = data_usa[(data_usa['Datetime']<pd.Timestamp(2021,6,1)) & (data_usa['Datetime']>pd.Timestamp(2020,12,1))]

# %%
states = data_usa_time['RegionName'].unique()
print(states)
# Out:
# ['Alaska' 'Alabama' 'Arkansas' 'Arizona' 'California' 'Colorado'
#  'Connecticut' 'Washington DC' 'Delaware' 'Florida' 'Georgia' 'Hawaii'
#  'Iowa' 'Idaho' 'Illinois' 'Indiana' 'Kansas' 'Kentucky' 'Louisiana'
#  'Massachusetts' 'Maryland' 'Maine' 'Michigan' 'Minnesota' 'Missouri'
#  'Mississippi' 'Montana' 'North Carolina' 'North Dakota' 'Nebraska'
#  'New Hampshire' 'New Jersey' 'New Mexico' 'Nevada' 'New York' 'Ohio'
#  'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Virginia' 'Vermont'
#  'Washington' 'Wisconsin' 'West Virginia' 'Wyoming']

# %%
import matplotlib.pyplot as plt

sns.lineplot(data=data_usa_time, x='Datetime', y='H7_Vaccination policy', hue="RegionCat")
plt.show()

# %%
feature = 'H7_Vaccination policy'
data_onereg = data_usa_time[data_usa_time['RegionCat']=='South']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('South')
plt.show()

data_onereg = data_usa_time[data_usa_time['RegionCat']=='Mid West']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('Mid West')
plt.show()

data_onereg = data_usa_time[data_usa_time['RegionCat']=='West']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('West')
plt.show()

# %% [markdown]
# ## Covid confirmed cases by region

# %%
feature = 'ConfirmedCases'
data_onereg = data_usa_time[data_usa_time['RegionCat']=='South']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('South')
plt.show()

data_onereg = data_usa_time[data_usa_time['RegionCat']=='Mid West']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('Mid West')
plt.show()

data_onereg = data_usa_time[data_usa_time['RegionCat']=='West']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('West')
plt.show()

# %% [markdown]
# ## Aggregated policies by groups

# %%
state_groups = [['Alaska', 'Connecticut', 'Florida', 'Georgia', 'Indiana', 'Louisiana', 'Mississippi', 'Missouri', 'South Carolina'], ['Alabama', 'California', 'Hawaii', 'Idaho', 'Illinois', 'Kentucky', 'Maine', 'Massachusetts', 'Michigan', 'Minnesota', 'Nevada', 'New York', 'North Carolina', 'Oklahoma', 'Rhode Island', 'South Dakota', 'Tennessee', 'Utah', 'Vermont', 'Washington', 'Wisconsin'], ['Arkansas', 'Maryland', 'Montana', 'Nebraska', 'New Hampshire', 'New Jersey', 'New Mexico', 'North Dakota', 'Ohio', 'Oregon', 'Pennsylvania', 'Texas', 'Virginia', 'Washington DC', 'West Virginia', 'Wyoming'], ['Arizona', 'Colorado', 'Delaware', 'Iowa', 'Kansas']]

# %%
features = ['GovernmentResponseIndexForDisplay','ContainmentHealthIndexForDisplay',
            'StringencyIndexForDisplay', 'EconomicSupportIndexForDisplay']
feature = features[3]

data_i = data_usa_time

for i in range(len(state_groups)):
    data_onereg = data_i[data_i['RegionName'].isin(state_groups[i])]
    sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
    plt.title('group '+chr(i+65))
    plt.show()

# %% [markdown]
# ## four aggregated policies

# %%
features = ['GovernmentResponseIndexForDisplay','ContainmentHealthIndexForDisplay',
            'StringencyIndexForDisplay', 'EconomicSupportIndexForDisplay']
feature = features[1]

data_i = data_usa_time
data_onereg = data_i[data_i['RegionCat']=='South']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('South')
plt.show()

data_onereg = data_i[data_i['RegionCat']=='Mid West']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('Mid West')
plt.show()

data_onereg = data_i[data_i['RegionCat']=='West']
sns.lineplot(data=data_onereg, x='Datetime', y=feature, hue="RegionName")
plt.title('West')
plt.show()

# %% [markdown]
# ## Face covering (part of government response and contarinment&health index)

# %%
sns.lineplot(data=data_usa, x='Datetime', y='ConfirmedCases', hue="RegionCat")

# %% [markdown]
# ## School closing

# %%
sns.lineplot(data=data_usa, x='Datetime', y='C1_School closing', hue="RegionCat")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

d = data_usa
# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
